# %% [markdown]
# ### 1- getting the data ready

# %%
import pandas as pd
import numpy as np

melhousing=pd.read_csv("C:\krh\dev\python\ml\datsets\melb_data.csv")
melhousing.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\k'
# <>:4: SyntaxWarning: invalid escape sequence '\k'
# C:\Users\kirol\AppData\Local\Temp\ipykernel_1600\1806828366.py:4: SyntaxWarning: invalid escape sequence '\k'
#   melhousing=pd.read_csv("C:\krh\dev\python\ml\datsets\melb_data.csv")
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# ...

# %% [markdown]
# ### create X features Matrix & Y labels

# %%
X=melhousing.drop("Price",axis=1)
Y=melhousing["Price"]

# %%
X.head()
# Out:
#        Suburb           Address  Rooms Type Method SellerG       Date  \
# 0  Abbotsford      85 Turner St      2    h      S  Biggin  3/12/2016
# 1  Abbotsford   25 Bloomburg St      2    h      S  Biggin  4/02/2016
# 2  Abbotsford      5 Charles St      3    h     SP  Biggin  4/03/2017
# 3  Abbotsford  40 Federation La      3    h     PI  Biggin  4/03/2017
# 4  Abbotsford       55a Park St      4    h     VB  Nelson  4/06/2016
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
Y.head()
# Out:
# 0    1480000.0
# 1    1035000.0
# 2    1465000.0
# 3     850000.0
# 4    1600000.0
# Name: Price, dtype: float64

# %% [markdown]
# ### 2- choose the right model and hyperparameters
#  in this case ..the problem we have is a regression problem

# %%
len(melhousing)
melhousing.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# ### trying SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

model=SGDRegressor()
model.fit(X_train,Y_train)

#reg=make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000, tol=1e-3))
#reg.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1600\1586104157.py in ?()
#       6 from sklearn.model_selection import train_test_split
#       7 X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
#       8
#       9 model=SGDRegressor()
# ---> 10 model.fit(X_train,Y_train)
#      11
#      12 #reg=make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000, tol=1e-3))
#      13 #reg.fit(X,Y)
#
# c:\Users\kirol\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ...
